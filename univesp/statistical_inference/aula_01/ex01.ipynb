# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../files/carst.csv')
print(df)
# Out:
#                          brand/model/year  cap_vol  consumo  power  weight  \
# 0                   Gurgel BR800 0.8 1991      792     12.0     33     650
# 1                  FIAT UNO Mille EP 1996      994     10.4     58     870
# 2                 Hyundai HB20 Sense 2020     1000     12.8     80     989
# 3                    FIAT Strada 1.4 2016     1368     10.3     86    1084
# 4                 VolksWagen GOL 1.6 2015     1598     10.5    104     961
# 5            Chevrolet Cruze LTZ 1.8 2016     1796      8.5    144    1427
# 6                    Honda Civic EXR 2016     1997      9.5    155    1294
# 7                 Ford Focus 2.0 GLX 2012     1999      9.2    148    1347
# 8                       BMW 325i 3.0 2012     2996      6.5    218    1460
# 9                 AUDI A4 3.2 V6 Fsi 2011     3197      7.1    269    1610
# 10      Mercedes-Benz CLS 350 3.5 V6 2012     3498      6.6    306    1735
# 11      Mercedes-Benz CLS 500 5.5 V8 2007     5461      4.2    388    1760
# 12        Chevrolet Camaro SS 6.2 V8 2018     6162      6.4    461    1709
# 13            Pagani Zonda F 7.3 V12 2006     7291      3.0    602    1230
# 14  Volkswagen Polo Highline 1.0 Tsi 2021      999     11.4    128    1147
# 15   Chevrolet Tracker Premier 1.2 T 2021     1199     11.2    133    1271
# 16         Chevrolet Cruze LTZ 1.4 T 2021     1399     11.0    153    1321
# 17         Honda Civic Touring 1.5 T 2021     1498     11.0    173    1329
# 18        Peugeot 306 Griffe 1.6 THP 2019     1598     10.6    173    1392
# 19       Audi A4 Attraction 1.8 TSFi 2015     1798      8.7    170    1470
# 20              BMW 320i Sport 2.0 T 2020     1998     10.5    184    1460
# 21           Porsche Panamera 3.0 V6 2018     2995      7.8    330    1815
# 22                Honda NSX 3.5 V6 T 2017     3493      7.0    507    1725
# 23         Nissan GTR Nismo 3.8 V6 T 2015     3799      5.0    608    1729
# 24    Mercedes-Benz E63 S AMG 4.0 V8 2021     3982      6.1    612    1935
# 25       Aston Martin DB11 5.2 V12 T 2017     5204      2.6    608    1770
# 26           Pagani Huayra 6.0 V12 T 2014     5980      3.0    730    1350
# 27            Bugatti Chiron 8.0 W16 2016     7993      3.8   1500    1998
#
#     cemm  nu_cy  Etype
# 0   34.4      2      0
# 1   18.6      4      0
# 2   14.5      3      0
# 3   12.5      4      0
# 4    9.8      4      0
# 5   10.2      4      0
# 6   10.9      4      0
# 7   10.4      4      0
# 8    7.1      6      0
# 9    6.4      6      0
# 10   6.1      6      0
# 11   5.4      8      0
# 12   4.2      8      0
# 13   3.6     12      0
# 14   9.6      3      1
# 15   9.4      3      1
# 16   9.0      4      1
# 17   8.6      4      1
# 18   8.3      4      1
# 19   8.3      4      1
# 20   7.1      4      1
# 21   5.7      6      1
# 22   3.3      6      1
# 23   2.7      6      1
# 24   3.4      8      1
# 25   3.9     12      1
# 26   3.3     12      1
# 27   2.5     16      1

# %%
df.head(15)
# Out:
#                          brand/model/year  cap_vol  consumo  power  weight  \
# 0                   Gurgel BR800 0.8 1991      792     12.0     33     650
# 1                  FIAT UNO Mille EP 1996      994     10.4     58     870
# 2                 Hyundai HB20 Sense 2020     1000     12.8     80     989
# 3                    FIAT Strada 1.4 2016     1368     10.3     86    1084
# 4                 VolksWagen GOL 1.6 2015     1598     10.5    104     961
# 5            Chevrolet Cruze LTZ 1.8 2016     1796      8.5    144    1427
# 6                    Honda Civic EXR 2016     1997      9.5    155    1294
# 7                 Ford Focus 2.0 GLX 2012     1999      9.2    148    1347
# 8                       BMW 325i 3.0 2012     2996      6.5    218    1460
# 9                 AUDI A4 3.2 V6 Fsi 2011     3197      7.1    269    1610
# 10      Mercedes-Benz CLS 350 3.5 V6 2012     3498      6.6    306    1735
# 11      Mercedes-Benz CLS 500 5.5 V8 2007     5461      4.2    388    1760
# 12        Chevrolet Camaro SS 6.2 V8 2018     6162      6.4    461    1709
# 13            Pagani Zonda F 7.3 V12 2006     7291      3.0    602    1230
# 14  Volkswagen Polo Highline 1.0 Tsi 2021      999     11.4    128    1147
#
#     cemm  nu_cy  Etype
# 0   34.4      2      0
# 1   18.6      4      0
# 2   14.5      3      0
# 3   12.5      4      0
# 4    9.8      4      0
# 5   10.2      4      0
# 6   10.9      4      0
# 7   10.4      4      0
# 8    7.1      6      0
# 9    6.4      6      0
# 10   6.1      6      0
# 11   5.4      8      0
# 12   4.2      8      0
# 13   3.6     12      0
# 14   9.6      3      1

# %%
print(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand/model/year  28 non-null     object
#  1   cap_vol           28 non-null     int64
#  2   consumo           28 non-null     float64
#  3   power             28 non-null     int64
#  4   weight            28 non-null     int64
#  5   cemm              28 non-null     float64
#  6   nu_cy             28 non-null     int64
#  7   Etype             28 non-null     int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 1.9+ KB
# None
#            cap_vol    consumo        power       weight       cemm      nu_cy  \
# count    28.000000  28.000000    28.000000    28.000000  28.000000  28.000000
# mean   3003.000000   8.096429   323.607143  1422.785714   8.542857   5.964286
# std    2043.372847   3.017171   307.036774   332.713686   6.342124   3.371802
# min     792.000000   2.600000    33.000000   650.000000   2.500000   2.000000
# 25%    1473.250000   6.325000   141.250000  1260.750000   4.125000   4.000000
# 50%    1998.500000   8.600000   178.500000  1409.500000   7.700000   4.000000
# 75%    3844.750000  10.525000   472.500000  1726.000000   9.900000   6.500000
# max    7993.000000  12.800000  1500.000000  1998.000000  34.400000  16.000000
#
#            Etype
# count  28.000000
# mean    0.500000
# std     0.509175
# min     0.000000
# 25%     0.000000
# 50%     0.500000
# 75%     1.000000
# max     1.000000

# %%
# %pip install -U stemgraphic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stemgraphic in /home/eliabe/.local/lib/python3.10/site-packages (0.9.1)
# Requirement already satisfied: docopt in /home/eliabe/.local/lib/python3.10/site-packages (from stemgraphic) (0.6.2)
# Requirement already satisfied: pandas in /home/eliabe/.local/lib/python3.10/site-packages (from stemgraphic) (2.1.1)
# Requirement already satisfied: seaborn in /home/eliabe/.local/lib/python3.10/site-packages (from stemgraphic) (0.12.2)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (from stemgraphic) (3.5.1)
# Requirement already satisfied: numpy>=1.22.4 in /home/eliabe/.local/lib/python3.10/site-packages (from pandas->stemgraphic) (1.26.0)
# Requirement already satisfied: tzdata>=2022.1 in /home/eliabe/.local/lib/python3.10/site-packages (from pandas->stemgraphic) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/eliabe/.local/lib/python3.10/site-packages (from pandas->stemgraphic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->stemgraphic) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->stemgraphic) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import stemgraphic

c1 = df.cap_vol
c2 = df.consumo
c3 = df.power
c4 = df.weight
c5 = df.cemm
c6 = df.nu_cy

stemgraphic.stem_graphic(c1, scale = 1000)
# Out:
# (<Figure size 750x300 with 1 Axes>, <Axes:>)

# %%
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':100})
plt.scatter(c1, c2, label=f'Correlação = {np.round(np.corrcoef(c1, c2)[0,1], 2)}')
plt.xlabel('Capacidade Volumétrica')
plt.ylabel('Consumo de combustível')
plt.title("Gráfico de dispersão: Consumo vs. capacidade volumétrica")
plt.legend()
plt.grid(True)
plt.show()

# %%
sns.jointplot(x=c1, y=c2)
# Out:
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df1 = pd.DataFrame(data=df)
plt.rcParams.update({'figure.figsize':(10, 8), 'figure.dpi':100})
sns.lmplot(x='cap_vol', y='consumo', hue='brand/model/year', data=df1)
# Out:
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/eliabe/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':100})
plt.scatter(c1, c3, label=f'Correlação = {np.round(np.corrcoef(c1, c3)[0,1], 2)}')
plt.xlabel('Capacidade Volumétrica')
plt.ylabel('Potência')
plt.title("Gráfico de dispersão: Capacidade volumétrica vs. Potência")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':100})
plt.scatter(c4, c5, label=f'Correlação: {np.round(np.corrcoef(c4, c5)[0,1], 2)}')
plt.xlabel('Peso')
plt.ylabel('0-100')
plt.title('Gráfico de dispersão: Peso vs. Aceleração')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Exercício 2
# O artigo "Alguma experiência de campo no uso de um método acelerado na estimativa da resistência do concreto em 28 dias" (*Some field experience in the use of an accelerated method in estimating 28-day strength of concrete*, J. of Amer. Concrete Institute, 1969: 895) fez a regressão de y = resistência do concreto usando tratamento padrão de 28 dias (1 psi = 7 KPa) em relação a x = resistência do concreto usando tratamento acelerado (psi).
#
# Suponha que a equação da reta de regressão verdadeira seja $y = 1800 + 1,3 x$.
#
# a. Qual é o valor esperado da resistência aos 28 dias quando a resistência usando o tratamento acelerado é igual a 2500?
#
# b. Até que ponto podemos esperar que a resistência aos 28 dias mude quando a resistência usando tratamento acelerado aumenta em 1 psi vezes?
#
# c. Responda ao item (b) para um aumento de 100 psi.
#
# d. Responda ao item (b) para uma diminuição de 100 psi.

# %% [markdown]
# ## Resposta a)
# Qual é o valor esperado da resistência aos 28 dias quando a resistência usando o tratamento acelerado é igual a 2500?
#
# Como $Y = \beta_0 + \beta_1 x_i$
#
# e $y = 1800 + 1,3 x$. Lembrando que:
#
# y = resistência do concreto usando tratamento padrão de 28 dias.
#
# x = resistência do concreto usando tratamento acelerado [psi] ou [libra-força por polegada quadrada].
#
# $\beta_0= 1800$ e $\beta_1= 1,3$
#
# O valor esperado de $Y$
#
# $\mu_{Y:x^*}  = \beta_0 + \beta_1 x_i$
#
# Substituindo com os dados indicados no item a, isto é $x=2500$
#
# $\mu_{Y:2500} = 1800 + 1,3(2500)$.

# %%
uy = 1800 + 1.3*2500
print(f'O valor esperado de ŷ para x = 2500 é: {uy}')
# Out:
# O valor esperado de ŷ para x = 2500 é: 5050.0

# %% [markdown]
# ## Resposta b)
# Até que ponto podemos esperar que a resistência aos 28 dias mude quando a resistência usando tratamento acelerado aumenta em 1 psi vezes?
#
# $y = 1800 + 1,3 x$.
#
# $\beta_0= 1800$ intercepto
#
# e $\beta_1= 1,3$ inclinação
#
# Mudança na variação é definida pela inclinação da reta ou seja $\beta_1$
#
# O valor esperado de $Y$ será $\beta_1 \times 1$
#
# $\beta_1 = 1,3$

# %% [markdown]
# # Exercício 3
# Em relação ao exercício anterior, suponha que o desvio padrão do desvio aleatório e seja 350 psi (1 psi = 7 KPa).
#
# a. Qual é a probabilidade de o valor observado de resistência aos 28 dias ultrapassar 5.000 psi, quando o valor da resistência usando trata-mento acelerado for 2.000?
#
# b. Repita o item (a), substituindo 2.000 por 2.500.
#
# c. Considere fazer duas observações independentes sobre a resistência aos 28 dias, a primeira para uma resistência usando tratamento acelerado de 2.000 e a segunda para x = 2.500. Qual é a probabilidade de que a segunda observação exceda a primeira em mais de 1.000 psi?
#
# d. Sejam Y1 e Y2 as observações sobre a resistên-cia aos 28 dias quando x = x1 e x = x2, respectivamente. Em quanto x2 excederia x1 para que P(Y2 > Y1) = 0,95?

# %% [markdown]
# ## Resposta a)
# Qual é a probabilidade de o valor observado de resistência aos 28 dias ultrapassar 5.000 psi, quando o valor da resistência usando tratamento acelerado for 2.000?
#
# **Dados**
# *   $\sigma = 350$ outra notação  $V= 350$
# *   Qual é a probabilidade de o valor observado de resistência aos 28 dias ultrapassar 5.000 psi --> $ Y = 1800 + 1,3x > 5000 $
# *   quando o valor da resistência usando tratamento acelerado for 2.000? --> $x=2000$
#
# O valor esperado de $Y$ para $x=2000$ usando $\mu_{Y:x^*}  = \beta_0 + \beta_1 x_i$ é
#
# $\mu_{Y:2000} = 1800 + 1,3(2000)$.

# %%
x=2000
uy= 1800 + 1.3*x
uy
print('O valor esperado de Y para x=2000 é =',uy)
# Out:
# O valor esperado de Y para x=2000 é = 4400.0

# %% [markdown]
# Considerando o desvio aleatório $\sigma = 350$, calcular $P(Y>5000)$ e considerando que o comportamento do desvio aleatório pode ser descrito mediante uma distribuição normal:
#
# $P(Y>5000)= P( Z > \frac{x-μ}{\sigma})$ ou
#
# $P(Y>5000 \space quando \space x=2000)= P( Z > \frac{Y-u_{y,2000}}{V})$
#
# $P(Y>5000)= P( Z > \frac{5000 - 4400}{350})$

# %% [markdown]
# **1º** Verificamos o valor para comparar com a [tabela Z](https://www.statology.org/z-table/)

# %%
y = 5000
uy = 4400
dp = 350
valor = (y-uy)/dp
valor
# Out:
# 1.7142857142857142

# %%
x = np.linspace(-2, 2, num = 100)
constant = 1/np.sqrt(2/np.pi)
pdf_normal_distribution = constant * np.exp((-x**2) / 2)
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(x, pdf_normal_distribution)
ax.set_ylim(0)
ax.set_title('Distribuição normal', size=16)
ax.set_ylabel('Densidade de Probabilidade', size=16)
# Out:
# Text(0, 0.5, 'Densidade de Probabilidade')

# %% [markdown]
# Podemos também usar uma biblioteca para nos ajudar nesse cálculo, que nos dará o mesmo valor encontrado na tabela-z

# %%
from scipy.integrate import quad

def normal_probability_density(x):
    constant = 1 / np.sqrt(2*np.pi)
    return(constant * np.exp((-x**2) / 2))
PZa,_ = quad(normal_probability_density, np.NINF, 1.71)
print(f'Phi(171) = {PZa}')
# Out:
# Phi(171) = 0.9563670634759682

# %%
PYm = 1-PZa
PYm
# Out:
# 0.043632936524031773
