# %%
import pandas as pd

data = pd.read_csv('files/indice.csv')

data.head()
# Out:
#    Unnamed: 0    Jan    Fev    Mar    Abr    Mai     Jun     Jul     Ago  \
# 0        2025  0,16%  1,31%     --     --     --      --      --      --
# 1        2024  0,42%  0,83%  0,16%  0,38%  0,46%   0,21%   0,38%  -0,02%
# 2        2023  0,53%  0,84%  0,71%  0,61%  0,23%  -0,08%   0,12%   0,23%
# 3        2022  0,54%  1,01%  1,62%  1,06%  0,47%   0,67%  -0,68%  -0,36%
# 4        2021  0,25%  0,86%  0,93%  0,31%  0,83%   0,53%   0,96%   0,87%
#
#       Set    Out    Nov    Dez     Ano
# 0      --     --     --     --   1,47%
# 1   0,44%  0,56%  0,39%  0,52%   4,83%
# 2   0,26%  0,24%  0,28%  0,56%   4,62%
# 3  -0,29%  0,59%  0,41%  0,62%   5,78%
# 4   1,16%  1,25%  0,95%  0,73%  10,06%

# %% [markdown]
# ## Renomeando colunas para facilitar o entendimento

# %%
data.rename(columns={"Ano": "Variação Anual", "Unnamed: 0": "Ano"}, inplace=True)
data.head()
# Out:
#     Ano    Jan    Fev    Mar    Abr    Mai     Jun     Jul     Ago     Set  \
# 0  2025  0,16%  1,31%     --     --     --      --      --      --      --
# 1  2024  0,42%  0,83%  0,16%  0,38%  0,46%   0,21%   0,38%  -0,02%   0,44%
# 2  2023  0,53%  0,84%  0,71%  0,61%  0,23%  -0,08%   0,12%   0,23%   0,26%
# 3  2022  0,54%  1,01%  1,62%  1,06%  0,47%   0,67%  -0,68%  -0,36%  -0,29%
# 4  2021  0,25%  0,86%  0,93%  0,31%  0,83%   0,53%   0,96%   0,87%   1,16%
#
#      Out    Nov    Dez Variação Anual
# 0     --     --     --          1,47%
# 1  0,56%  0,39%  0,52%          4,83%
# 2  0,24%  0,28%  0,56%          4,62%
# 3  0,59%  0,41%  0,62%          5,78%
# 4  1,25%  0,95%  0,73%         10,06%

# %% [markdown]
# ## Alterando os tipos de dados
# ### Atualmente, nossos dados estão como string, ou obj

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ano             26 non-null     int64
#  1   Jan             26 non-null     object
#  2   Fev             26 non-null     object
#  3   Mar             26 non-null     object
#  4   Abr             26 non-null     object
#  5   Mai             26 non-null     object
#  6   Jun             26 non-null     object
#  7   Jul             26 non-null     object
#  8   Ago             26 non-null     object
#  9   Set             26 non-null     object
#  10  Out             26 non-null     object
#  11  Nov             26 non-null     object
#  12  Dez             26 non-null     object
#  13  Variação Anual  26 non-null     object
# dtypes: int64(1), object(13)
# memory usage: 3.0+ KB

# %%
for column in data.columns[1:]: # não vamos mexer na coluna "Ano"
    print(column)
    data[column] = data[column].str.replace(',', '.').replace('%', '').astype('float64')
    # data[column] = data[column].str.replace('%', '').astype('float64')

data.head()
# Out:
# Jan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 3
#       1 for column in data.columns[1:]: # não vamos mexer na coluna "Ano"
#       2     print(column)
# ----> 3     data[column] = data[column].str.replace('--', '0').replace(',', '.').replace('%', '').astype('float64')
#       4     # data[column] = data[column].str.replace('%', '').astype('float64')
#       6 data.head()
#
# File ~/Dev/Python/Data/DS Bootcamp/.conda/lib/python3.10/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...
