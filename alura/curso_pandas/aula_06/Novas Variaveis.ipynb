# %% [markdown]
# # Relatório de Análise VI

# %% [markdown]
# ## Criando Novas Variáveis

# %%
import pandas as pd
dados = pd.read_csv('../dados/aluguel_residencial.csv', sep=';')

# %%
dados['Valor Bruto'] = dados.Valor + dados.Condominio + dados.IPTU
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado  Valor Bruto
# 0      1700.0       500.0  60.0     42.50   Apartamento       2260.0
# 1      7000.0         0.0   0.0     70.00          Casa       7000.0
# 2       800.0       390.0  20.0     53.33   Apartamento       1210.0
# 3       800.0       230.0   0.0     16.67   Apartamento       1030.0
# 4      1300.0       301.0  17.0     26.00   Apartamento       1618.0
# ...       ...         ...   ...       ...           ...          ...
# 21821   900.0       490.0  48.0     12.86   Apartamento       1438.0
# 21822   800.0       350.0  25.0     29.63   Apartamento       1175.0
# 21823  1800.0       800.0  40.0     23.08   Apartamento       2640.0
# 21824  1400.0       509.0  37.0     29.17   Apartamento       1946.0
# 21825  3000.0       760.0   0.0     42.86   Apartamento       3760.0
#
# [21826 rows x 12 columns]

# %%
dados['Valor m2'] = (dados['Valor'] / dados.Area).round(2)
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado  Valor Bruto
# 0      1700.0       500.0  60.0     42.50   Apartamento       2260.0
# 1      7000.0         0.0   0.0     70.00          Casa       7000.0
# 2       800.0       390.0  20.0     53.33   Apartamento       1210.0
# 3       800.0       230.0   0.0     16.67   Apartamento       1030.0
# 4      1300.0       301.0  17.0     26.00   Apartamento       1618.0
# ...       ...         ...   ...       ...           ...          ...
# 21821   900.0       490.0  48.0     12.86   Apartamento       1438.0
# 21822   800.0       350.0  25.0     29.63   Apartamento       1175.0
# 21823  1800.0       800.0  40.0     23.08   Apartamento       2640.0
# 21824  1400.0       509.0  37.0     29.17   Apartamento       1946.0
# 21825  3000.0       760.0   0.0     42.86   Apartamento       3760.0
#
# [21826 rows x 12 columns]

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados.Area).round(2)
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado  Valor Bruto  \
# 0      1700.0       500.0  60.0     42.50   Apartamento       2260.0
# 1      7000.0         0.0   0.0     70.00          Casa       7000.0
# 2       800.0       390.0  20.0     53.33   Apartamento       1210.0
# 3       800.0       230.0   0.0     16.67   Apartamento       1030.0
# 4      1300.0       301.0  17.0     26.00   Apartamento       1618.0
# ...       ...         ...   ...       ...           ...          ...
# 21821   900.0       490.0  48.0     12.86   Apartamento       1438.0
# 21822   800.0       350.0  25.0     29.63   Apartamento       1175.0
# 21823  1800.0       800.0  40.0     23.08   Apartamento       2640.0
# 21824  1400.0       509.0  37.0     29.17   Apartamento       1946.0
# 21825  3000.0       760.0   0.0     42.86   Apartamento       3760.0
#
#        Valor Bruto m2
# 0               56.50
# 1               70.00
# 2               80.67
# 3               21.46
# 4               32.36
# ...               ...
# 21821           20.54
# 21822           43.52
# 21823           33.85
# 21824           40.54
# 21825           53.71
#
# [21826 rows x 13 columns]

# %%
casas = ['Casa', 'Casa de Condomínio', 'Casa de Vila']
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casas else 'Apartamento')
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado  Valor Bruto  \
# 0      1700.0       500.0  60.0     42.50   Apartamento       2260.0
# 1      7000.0         0.0   0.0     70.00          Casa       7000.0
# 2       800.0       390.0  20.0     53.33   Apartamento       1210.0
# 3       800.0       230.0   0.0     16.67   Apartamento       1030.0
# 4      1300.0       301.0  17.0     26.00   Apartamento       1618.0
# ...       ...         ...   ...       ...           ...          ...
# 21821   900.0       490.0  48.0     12.86   Apartamento       1438.0
# 21822   800.0       350.0  25.0     29.63   Apartamento       1175.0
# 21823  1800.0       800.0  40.0     23.08   Apartamento       2640.0
# 21824  1400.0       509.0  37.0     29.17   Apartamento       1946.0
# 21825  3000.0       760.0   0.0     42.86   Apartamento       3760.0
#
#        Valor Bruto m2
# 0               56.50
# 1               70.00
# 2               80.67
# 3               21.46
# 4               32.36
# ...               ...
# 21821           20.54
# 21822           43.52
# 21823           33.85
# 21824           40.54
# 21825           53.71
#
# [21826 rows x 13 columns]

# %%
dados[dados.Tipo == 'Casa de Condomínio']
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 5      Casa de Condomínio          Barra da Tijuca        5      4       5
# 6      Casa de Condomínio                    Ramos        2      2       0
# 12     Casa de Condomínio                  Taquara        3      1       1
# 16     Casa de Condomínio          Barra da Tijuca        4      3       2
# 42     Casa de Condomínio          Barra da Tijuca        5     10       5
# ...                   ...                      ...      ...    ...     ...
# 21764  Casa de Condomínio          Barra da Tijuca        4      3       4
# 21782  Casa de Condomínio          Barra da Tijuca        5      2       5
# 21791  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 21801  Casa de Condomínio          Barra da Tijuca        3      5       3
# 21820  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#        Area    Valor  Condominio    IPTU  Valor m2 Tipo Agregado  Valor Bruto  \
# 5       750  22000.0         0.0     0.0     29.33          Casa      22000.0
# 6        65   1000.0         0.0     0.0     15.38          Casa       1000.0
# 12      115   2000.0         0.0     0.0     17.39          Casa       2000.0
# 16      466   7500.0      2695.0     0.0     16.09          Casa      10195.0
# 42     1600  25000.0      1600.0     0.0     15.62          Casa      26600.0
# ...     ...      ...         ...     ...       ...           ...          ...
# 21764   460  12000.0      1000.0  1200.0     26.09          Casa      14200.0
# 21782   554  20000.0      1892.0  1743.0     36.10          Casa      23635.0
# 21791   155   2000.0       530.0  1250.0     12.90          Casa       3780.0
# 21801  1000  20000.0      3000.0     0.0     20.00          Casa      23000.0
# 21820   450  15000.0      1711.0  2332.0     33.33          Casa      19043.0
#
#        Valor Bruto m2
# 5               29.33
# 6               15.38
# 12              17.39
# 16              21.88
# 42              16.62
# ...               ...
# 21764           30.87
# 21782           42.66
# 21791           24.39
# 21801           23.00
# 21820           42.32
#
# [996 rows x 13 columns]

# %% [markdown]
# ## Removendo Campos

# %%
dados_aux = pd.DataFrame(dados[['Tipo Agregado', 'Valor m2', 'Valor Bruto', 'Valor Bruto m2']])
dados_aux
# Out:
#       Tipo Agregado  Valor m2  Valor Bruto  Valor Bruto m2
# 0       Apartamento     42.50       2260.0           56.50
# 1              Casa     70.00       7000.0           70.00
# 2       Apartamento     53.33       1210.0           80.67
# 3       Apartamento     16.67       1030.0           21.46
# 4       Apartamento     26.00       1618.0           32.36
# ...             ...       ...          ...             ...
# 21821   Apartamento     12.86       1438.0           20.54
# 21822   Apartamento     29.63       1175.0           43.52
# 21823   Apartamento     23.08       2640.0           33.85
# 21824   Apartamento     29.17       1946.0           40.54
# 21825   Apartamento     42.86       3760.0           53.71
#
# [21826 rows x 4 columns]

# %%
del dados_aux['Valor Bruto']
dados_aux
# Out:
#       Tipo Agregado  Valor m2  Valor Bruto m2
# 0       Apartamento     42.50           56.50
# 1              Casa     70.00           70.00
# 2       Apartamento     53.33           80.67
# 3       Apartamento     16.67           21.46
# 4       Apartamento     26.00           32.36
# ...             ...       ...             ...
# 21821   Apartamento     12.86           20.54
# 21822   Apartamento     29.63           43.52
# 21823   Apartamento     23.08           33.85
# 21824   Apartamento     29.17           40.54
# 21825   Apartamento     42.86           53.71
#
# [21826 rows x 3 columns]

# %%
dados_aux.pop('Valor Bruto m2')
dados_aux
# Out:
#       Tipo Agregado  Valor m2
# 0       Apartamento     42.50
# 1              Casa     70.00
# 2       Apartamento     53.33
# 3       Apartamento     16.67
# 4       Apartamento     26.00
# ...             ...       ...
# 21821   Apartamento     12.86
# 21822   Apartamento     29.63
# 21823   Apartamento     23.08
# 21824   Apartamento     29.17
# 21825   Apartamento     42.86
#
# [21826 rows x 2 columns]

# %%
dados.drop(['Valor Bruto', 'Valor Bruto m2'], axis=1, inplace=True)
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0      1700.0       500.0  60.0     42.50   Apartamento
# 1      7000.0         0.0   0.0     70.00          Casa
# 2       800.0       390.0  20.0     53.33   Apartamento
# 3       800.0       230.0   0.0     16.67   Apartamento
# 4      1300.0       301.0  17.0     26.00   Apartamento
# ...       ...         ...   ...       ...           ...
# 21821   900.0       490.0  48.0     12.86   Apartamento
# 21822   800.0       350.0  25.0     29.63   Apartamento
# 21823  1800.0       800.0  40.0     23.08   Apartamento
# 21824  1400.0       509.0  37.0     29.17   Apartamento
# 21825  3000.0       760.0   0.0     42.86   Apartamento
#
# [21826 rows x 11 columns]

# %%
dados.to_csv('../dados/aluguel_residencial.csv', sep=';', index=False)
